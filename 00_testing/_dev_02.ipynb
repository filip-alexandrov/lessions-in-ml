# %%
import sponsorblock as sb

client = sb.Client() 
segments = client.get_skip_segments("https://www.youtube.com/watch?v=FfgT6zx4k3Q")
segments
# Out:
# Setting SPONSORBLOCK_USER_ID environment variable
# [Segment(category=intro, start=19.676, end=28.049, uuid=16a93852e4b026c6b39aaba5e749be613d7408d082d675e7956138321d4b4ffa6, duration=0:00:08.373000, action_type=skip),
#  Segment(category=outro, start=445.905, end=455.481, uuid=c22e41c3e2959021076aad5056c4fce83b68e4a1b45f16ec910cae61a0c60f506, duration=0:00:09.576000, action_type=skip),
#  Segment(category=poi_highlight, start=394.068, end=394.068, uuid=2767b5752459c02ec54fc286dc34778f648eeff87f97315149ad5743ec0096846, duration=0:00:00, action_type=skip)]

# %%
import json
import yt_dlp

URL = 'https://www.youtube.com/watch?v=BaW_jenozKc'

# ℹ️ See help(yt_dlp.YoutubeDL) for a list of available options and public functions
ydl_opts = {
    'format': 'bestaudio/best',
    'postprocessors': [{
        'key': 'FFmpegExtractAudio',
        'preferredcodec': 'mp3',
        'preferredquality': '192',
    }],
}

with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    ydl.download([URL])
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=BaW_jenozKc
# [youtube] BaW_jenozKc: Downloading webpage
# [youtube] BaW_jenozKc: Downloading android player API JSON
# [info] BaW_jenozKc: Downloading 1 format(s): 251
# [dashsegments] Total fragments: 1
# [download] Destination: youtube-dl test video ＂'⧸⧹ä↭𝕐 [BaW_jenozKc].webm
# [download] 100% of  138.96KiB in 00:00:00 at 222.80KiB/s
# [ExtractAudio] Destination: youtube-dl test video ＂'⧸⧹ä↭𝕐 [BaW_jenozKc].mp3
# Deleting original file youtube-dl test video ＂'⧸⧹ä↭𝕐 [BaW_jenozKc].webm (pass -k to keep)

# %%
import yt_dlp as youtube_dl

# Set the YouTube video URL and video ID
video_id = 'Hwybp38GnZw'
video_url = f'https://www.youtube.com/watch?v={video_id}'

# Set the output filename
output_template = f'{video_id}.%(ext)s'

# Create a YouTubeDL object with audio-only format options
ydl_opts = {
    'format': 'bestaudio/best',
    'outtmpl': output_template,
}

# Create a downloader object with the specified options
ydl = youtube_dl.YoutubeDL(ydl_opts)

# Download the audio
ydl.download([video_url])
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Hwybp38GnZw
# [youtube] Hwybp38GnZw: Downloading webpage
# [youtube] Hwybp38GnZw: Downloading android player API JSON
# [info] Hwybp38GnZw: Downloading 1 format(s): 251-12
# [dashsegments] Total fragments: 2
# [download] Destination: Hwybp38GnZw.webm
# [download] 100% of   15.09MiB in 00:00:02 at 7.08MiB/s
# 0

# %%
from youtube_transcript_api import YouTubeTranscriptApi
video_id = 'Hwybp38GnZw'
YouTubeTranscriptApi.get_transcript(video_id)
# Out:
# [{'text': "i recreated willy wonka's chocolate",
#   'start': 0.0,
#   'duration': 4.0},
#  {'text': 'factory in real life and one of these 10',
#   'start': 1.92,
#   'duration': 3.76},
#  {'text': 'people is going to walk away with this',
#   'start': 4.0,
#   'duration': 4.48},
#  {'text': 'chocolate factory', 'start': 5.68, 'duration': 2.8},
#  {'text': 'wow yo welcome to my wonderful creation',
#   'start': 11.04,
#   'duration': 6.96},
#  {'text': 'oh my gosh it is candy land here look at',
#   'start': 14.639,
#   'duration': 5.601},
#  {'text': "the river it's a chocolate door oh he's",
#   'start': 18.0,
#   'duration': 3.92},
#  {'text': "taking a bite out of our door that's",
#   'start': 20.24,
#   'duration': 3.52},
#  {'text': 'good these ten contestants are all here',
#   'start': 21.92,
#   'duration': 3.359},
#  {'text': 'because they found a golden ticket when',
#   'start': 23.76,
#   'duration': 3.12},
#  {'text': 'they bought one of our pistol bars for',
# ...
